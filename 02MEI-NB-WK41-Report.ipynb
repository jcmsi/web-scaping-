# %%
#pip install openpyxl
# Out:
# ...
#
# ...

# %%
import pandas as pd
#import openpyxl

# %%
wk = pd.read_excel('01-MEI-DataPull-WK41.xlsx')

wk.head()
# Out:
#    Unnamed: 0                                               name     SKU  \
# 0           0  MSI Raider GE78HX 13VI-086US 17" Gaming Laptop...  535070
# 1           1  Acer Predator Helios 16 PH16-71-948L 16" Gamin...  554253
# 2           2  ASUS ROG Zephyrus Duo 16 GX650PY-XS97 16" Gami...  557918
# 3           3  ASUS ROG Strix SCAR 17 G733PYV-XH97 17.3" Gami...  605832
# 4           4  HP Victus 16-r0073cl 16.1" Gaming Laptop Compu...  607788
#
#      price  instock_x  instock_y  discount
# 0  2999.99  8IN STOCK  8IN STOCK   $1,000.
# 1  1799.99  1IN STOCK  1IN STOCK   $400.00
# 2  3299.99  0IN STOCK  0IN STOCK   $700.00
# 3  3499.99  1IN STOCK  1IN STOCK   $200.00
# 4   799.99  2IN STOCK        NaN       NaN

# %%
df = pd.read_excel('MicrocenterCompetitor093024.xlsx', sheet_name='Gaming Notebook')

df
# Out:
#      Gaming Notebook Unnamed: 1              Unnamed: 2 Unnamed: 3  \
# 0              Specs        NaN                     NaN        NaN
# 1            Channel      Brand                   Model     Screen
# 2    microcenter.com        MSI             Titan 18 HX        18"
# 3    microcenter.com      Razer         Blade 18 (2024)        18"
# 4    microcenter.com     Lenovo         Legion 9 16IRX9        16"
# ..               ...        ...                     ...        ...
# 124  microcenter.com       Asus          TUF Gaming A16        16"
# 125  microcenter.com         HP      Victus 15-fb0121nr      15.6"
# 126  microcenter.com       Acer   Nitro V ANV15-51-54UL      15.6"
# 127  microcenter.com       Asus          TUF Gaming F15      15.6"
# 128  microcenter.com        MSI  Thin 15 B12UCX-2425US       15.6"
#
#       Unnamed: 4    Unnamed: 5          Unnamed: 6           Unnamed: 7  \
# 0            NaN           NaN                 NaN                  NaN
# ...

# %%
df.columns = df.iloc[1]

df
# Out:
# 1            Channel   Brand                   Model  Screen   Resolution  \
# 0              Specs     NaN                     NaN     NaN          NaN
# 1            Channel   Brand                   Model  Screen   Resolution
# 2    microcenter.com     MSI             Titan 18 HX     18"  3840 x 2400
# 3    microcenter.com   Razer         Blade 18 (2024)     18"  2560 x 1600
# 4    microcenter.com  Lenovo         Legion 9 16IRX9     16"  3200 x 2000
# ..               ...     ...                     ...     ...          ...
# 124  microcenter.com    Asus          TUF Gaming A16     16"  1920 x 1200
# 125  microcenter.com      HP      Victus 15-fb0121nr   15.6"  1920 x 1080
# 126  microcenter.com    Acer   Nitro V ANV15-51-54UL   15.6"  1920 x 1080
# 127  microcenter.com    Asus          TUF Gaming F15   15.6"  1920 x 1080
# 128  microcenter.com     MSI  Thin 15 B12UCX-2425US    15.6"  1920 x 1080
#
# 1    Refresh Rate                 CPU                  GPU  Memory     SSD  \
# ...

# %%
df = df.iloc[2:]

df
# Out:
# 1            Channel   Brand                   Model Screen   Resolution  \
# 2    microcenter.com     MSI             Titan 18 HX    18"  3840 x 2400
# 3    microcenter.com   Razer         Blade 18 (2024)    18"  2560 x 1600
# 4    microcenter.com  Lenovo         Legion 9 16IRX9    16"  3200 x 2000
# 5    microcenter.com   Razer         Blade 16 (2024)    16"   2560 x1600
# 6    microcenter.com     MSI           Raider GE78HX    17"  2560 x 1600
# ..               ...     ...                     ...    ...          ...
# 124  microcenter.com    Asus          TUF Gaming A16    16"  1920 x 1200
# 125  microcenter.com      HP      Victus 15-fb0121nr  15.6"  1920 x 1080
# 126  microcenter.com    Acer   Nitro V ANV15-51-54UL  15.6"  1920 x 1080
# 127  microcenter.com    Asus          TUF Gaming F15  15.6"  1920 x 1080
# 128  microcenter.com     MSI  Thin 15 B12UCX-2425US   15.6"  1920 x 1080
#
# 1   Refresh Rate                 CPU                  GPU Memory     SSD  ...  \
# ...

# %%
df1 = pd.merge(df, wk, on=['SKU'], how='left')

df1
# Out:
#              Channel   Brand                   Model Screen   Resolution  \
# 0    microcenter.com     MSI             Titan 18 HX    18"  3840 x 2400
# 1    microcenter.com   Razer         Blade 18 (2024)    18"  2560 x 1600
# 2    microcenter.com  Lenovo         Legion 9 16IRX9    16"  3200 x 2000
# 3    microcenter.com   Razer         Blade 16 (2024)    16"   2560 x1600
# 4    microcenter.com     MSI           Raider GE78HX    17"  2560 x 1600
# ..               ...     ...                     ...    ...          ...
# 122  microcenter.com    Asus          TUF Gaming A16    16"  1920 x 1200
# 123  microcenter.com      HP      Victus 15-fb0121nr  15.6"  1920 x 1080
# 124  microcenter.com    Acer   Nitro V ANV15-51-54UL  15.6"  1920 x 1080
# 125  microcenter.com    Asus          TUF Gaming F15  15.6"  1920 x 1080
# 126  microcenter.com     MSI  Thin 15 B12UCX-2425US   15.6"  1920 x 1080
#
#     Refresh Rate                 CPU                  GPU Memory     SSD  ...  \
# ...

# %% [markdown]
# # CSV

# %%
with pd.ExcelWriter('02MEI-NB-WK39-Report.xlsx') as writer:
    df1.to_excel(writer, sheet_name='NB')
